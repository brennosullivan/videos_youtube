# %% [markdown]
# ## O que é o Jupyter Notebook?
#
# * É um ambiente que você dará os comandos pro computador.
# * O computador irá respeitar a ordem dos comandos que você digitar.
#
# ## Atalhos Jupyter
#
# * Nova célula: B
# * Deletar um célula: DD
# * Rodar o código: CTRL + ENTER
# * Transformar a célula em Markodown: M
# * Reveter e transformar em código: Y
# * Tudo pode ser feito através do Botões

# %%
nome = 'Leandro'

print("Estamos aprendendo Python")
print("Meu aluno se chama " + nome)
print("e o " + nome + " irá aprender a programar hoje")

# %% [markdown]
# ### As variáveis são incríveis formas de controlar os dados dentro dos programas.

# %% [markdown]
# # Tipos de dados
#
# * String
# * Inteiro
# * Float
# * Booleano

# %%
nome = 'Andrea' 
anos_aluno = 20
altura_aluno = 1.54
masculino = False

print(masculino)

# %% [markdown]
# # Como lidar com strings
#
# * Como colocar palavras em maiúsculo?
# * Como selecionar letras dentro de palavras?
# * Como saber o tamanho de uma frase?

# %%
frase = "eu amo finanças"

frase_maior = frase.upper()
frase_menor = frase.lower()
frase_de_titulo = frase.title()

frase_maior.lower().islower()
frase_maior.isupper()


print()

# %% [markdown]
# # Como selecionar letras dentro da frase

# %%
print(frase[0:2])
print(frase[0])
print(frase[-1])
print(frase[1: ])
print(len(frase))

frase_flamenguista = frase.replace("finanças", "Flamengo")

print(frase_flamenguista)

# %% [markdown]
# # Como colocar variáveis dentro de textos

# %%
empresa = "Itau"
anos = "50"
anos_em_numero = 50

print("Vou investir na empresa " + empresa + " que possui " + anos + " anos de existência.")

print(f"Vou investir na empresa {empresa} que possui {anos_em_numero} anos de existência.")

ano_fundacao = 2023 - anos_em_numero

print(f"Vou investir na empresa {empresa} que possui {anos_em_numero} anos e foi fundada em {ano_fundacao}.")

# %% [markdown]
# # Como lidar com números e operações aritméricas

# %%
inteiro = 30
numero_decimal = 1.54

convertendo_texto_para_inteiro = int("50")
convertendo_texto_para_float = float("50.45")

print(type(convertendo_texto_para_float))
print(convertendo_texto_para_float)

# %% [markdown]
# # Operações aritméticas
#
# ### Ordem operações:
#
# ![image.png](attachment:image.png)

# %%
soma = 2 + 2
diminuir = 10 - 8
dividir = 10 / 2
multiplicar = 100 * 8
exponenciar =  2 ** 5
dividir_inteiro = 5//2
resto_divisao = 5 % 2

equacao = (10 + 5) * 2 ** 2 - 6 / 3

print(soma)
print(diminuir)
print(dividir)
print(multiplicar)
print(exponenciar)
print(dividir_inteiro)
print(resto_divisao)

print(equacao)

# %% [markdown]
# # Funções matemáticas úteis nativas do Python

# %%
numero_maximo = max(4, 10)
numero_minimo = min(4, 10)

rentabilidade_ibovespa = round(0.45634635155, 2)

print(rentabilidade_ibovespa)

# %% [markdown]
# # Como coletar dados de usuários

# %%
nome = input("Qual é o seu nome? ")
idade = int(input("Qual é a sua idade? "))

ano_nascimento = 2023 - idade

print(f"Olá {nome}, seja muito bem vindo, soube que você tem {idade} anos!")
print(f"Dito isso, você nasceu no ano de {ano_nascimento}")

# %% [markdown]
# # Comentários em códigos

# %%
#Aqui vamos prosseguir com o curso


'''você pode comentar assim
você pode comentar várias linhas
sem problema 
nenhum

'''

print("Vamos prosseguir")

# %% [markdown]
# # Projeto criando uma calculadora de juros compostos
#
# * Fórmula de juros compostos: montante = inicial * (1 + taxa) ** tempo

# %%
nome = input("Qual o seu nome? ")

print(f"Olá {nome}, seja muito bem vindo aos juros compostos! Aqui nós cuidamos da sua aposentadoria :)")

dinheiro_inicial = int(input("Digite a quantidade de dinheiro inicial do investimento: "))
tempo = int(input("Digite quantos anos você deixará o dinheiro investido: "))
taxa = float(input("Digite, em decimal, qual a taxa anual de retorno do seu investimento: "))

montante = dinheiro_inicial * (1 + taxa) ** tempo
montante = round(montante, 2)

print('---------------------------------------------')

print(f"Parabéns {nome}! Ao final do período você terá R${montante}!")

#mas e os aportes? 
#como eu sei q cheguei a liberdade financeira?

# %% [markdown]
# # Listas

# %%
lista_de_nomes = ["brenno", "leandro", "lucas"]
#                     0         1         2

lista_de_nomes[0:2]
lista_de_nomes[-1]

# %% [markdown]
# # Funções de listas

# %%
bancos = ['Itau', 'Bradesco', 'Banco do Brasil']
preco_acoes = [20, 15, 10]

print(bancos)

# %%
#Adicionar novos dados a listas

bancos.append("Santander")
preco_acoes.append(30)

print(preco_acoes)

# %%
#adicionar um novo dado em uma posição específica

bancos.insert(1, "inter")

print(bancos)

# %%
#remover um item da lista

bancos.remove("Santander")

print(bancos)

# %%
#ordenar uma lista 

preco_acoes.sort()

print(preco_acoes)

# %% [markdown]
# # Condicionais
#
#
# Se o dinheiro que você tem é menor que 20 reais:
#
#     Invista em você mesmo
#
# Caso o dinheiro for maior que 20 e menor que 1000:
#
#     Comece a montar uma carteira de investimento
#
# Para todos os outros cenários:
#
#     Invista pesado e se aposente cedo.
#
#
# As indentações são estruturas fundamentais no Python

# %%
dinheiro = int(input("Quanto dinheiro você tem para investir? "))

if dinheiro <= 20:
    
    print("Invista em você mesmo")
    
elif dinheiro > 20 and dinheiro <= 1000:
    
    print("Comece a montar uma carteira de investimento")
    
else:
    
    print("Invista pesado e se aposente cedo")

# %%
metodo_pagamento = input("Qual seu método de pagamento? ")

if metodo_pagamento == "pix" or metodo_pagamento == "cartão":
    
    print("Podemos receber seu pagamento!")
    
elif metodo_pagamento == "dinheiro":
    
    print("Infelizmente não podemos aceitar pois não vivemos mais como os Incás :(")
    
else:
    
    print("Não conheço esse tipo de dinheiro!")

# %% [markdown]
# # Projeto criando uma calculadora de juros compostos
#
# * Adicionando funcionalidade de liberdade financeira

# %%
nome = input("Qual o seu nome? ")

print(f"Olá {nome}, seja muito bem vindo aos juros compostos! Aqui nós cuidamos da sua aposentadoria :)")

dinheiro_inicial = int(input("Digite a quantidade de dinheiro inicial do investimento: "))
tempo = int(input("Digite quantos anos você deixará o dinheiro investido: "))
taxa = float(input("Digite, em decimal, qual a taxa anual de retorno do seu investimento: "))
salario_desejado = int(input("Digite o salário mensal que você quer receber ao se aposentar: "))

montante = dinheiro_inicial * (1 + taxa) ** tempo
montante = round(montante, 2)

print('---------------------------------------------')

print(f"Parabéns {nome}! Ao final do período você terá R${montante}!")

salario_mensal = (montante * taxa)/12
salario_mensal = round(salario_mensal, 2)

if salario_mensal >= salario_desejado:
    
    print(f"Parabéns, você pode se aposentar! Seu salário mensal com esse montante é de R$ {salario_mensal}")
    
    
elif salario_mensal < salario_desejado:
    
    print(f"Infelizmente se aposentar não será possível. Com esse montante seu salário mensal é de R$ {salario_mensal}")
    
    
    
#cade os aportes?

# %% [markdown]
# # Loop While
#
# * O programa nunca para de rodar enquanto a condição não se satisfaz

# %%
meta_vendas = 10
vendas = 0

while vendas < meta_vendas:
    
    print(f"Total de vendas: {vendas}! Trabalhem mais")
    
    vendas = vendas + 1

    
print("Meta batida")

# %%
i = 0

while i < 10:
    
    print(i)
    
    i = i + 1

# %% [markdown]
# # For loop
#
# * A cada elemento x, faça y.

# %%
bancos = ['Itau', 'Bradesco', 'Banco do Brasil']
cotacoes = [10, 20, 30]

for banco in bancos:
    
    print(banco)

# %%
for i in range(0, len(bancos)):
    
    print(i)
    print(bancos[i], cotacoes[i])
    print(f"O preço da ação {bancos[i]} é {cotacoes[i]}")

# %%
cotacoes = [10, 20, 30]

for preco in cotacoes:
    
    print(preco)

# %% [markdown]
# # Gran finale - Colocando aporte na calculadora de juros compostos!

# %%
nome = input("Qual o seu nome? ")

print(f"Olá {nome}, seja muito bem vindo aos juros compostos! Aqui nós cuidamos da sua aposentadoria :)")

dinheiro_inicial = int(input("Digite a quantidade de dinheiro inicial do investimento: "))
tempo_desejado = int(input("Digite quantos meses você deixará o dinheiro investido: "))
taxa = float(input("Digite, em decimal, qual a taxa mensal de retorno do seu investimento: "))
aporte = int(input("Quanto dinheiro você consegue aportar por mês: "))
salario_desejado = int(input("Digite o salário mensal que você quer receber ao se aposentar: "))


tempo_decorrido = 0

while tempo_decorrido < tempo_desejado:
    
    if tempo_decorrido == 0:
        
        montante = dinheiro_inicial * (1 + taxa) ** 1
        montante = round(montante, 2)
        tempo_decorrido = tempo_decorrido + 1
        
    else:
        
        montante = (montante + aporte) * (1 + taxa) ** 1
        montante = round(montante, 2)
        tempo_decorrido = tempo_decorrido + 1
        

print('---------------------------------------------')

print(f"Parabéns {nome}! Ao final do período você terá R${montante}!")

salario_mensal = (montante * taxa)
salario_mensal = round(salario_mensal, 2)

if salario_mensal >= salario_desejado:
    
    print(f"Parabéns, você pode se aposentar! Seu salário mensal com esse montante é de R$ {salario_mensal}")
    
    
elif salario_mensal < salario_desejado:
    
    print(f"Infelizmente se aposentar não será possível. Com esse montante seu salário mensal é de R$ {salario_mensal}")
